# %%
# !pip install pymongo
import pymongo
cli = pymongo.MongoClient(host='34.210.97.79')
# Out:
# Requirement already satisfied (use --upgrade to upgrade): pymongo in /opt/conda/lib/python3.5/site-packages
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
cli.database_names()
# Out:
# ['admin', 'local', 'wiki_mongo_database', 'wiki_mongo_db']

# %%
import pandas as pd
import numpy as np
from IPython import display
from bs4 import BeautifulSoup
import requests
# !pip install nltk
import nltk

import re
from spacy.en import STOP_WORDS
from spacy.en import English
nlp = English()
# Out:
# Requirement already satisfied (use --upgrade to upgrade): nltk in /opt/conda/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): six in /opt/conda/lib/python3.5/site-packages (from nltk)
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-4-6d39b1ca1c8d> in <module>()
#      10 from spacy.en import STOP_WORDS
#      11 from spacy.en import English
# ---> 12 nlp = English()
#
# /opt/conda/lib/python3.5/site-packages/spacy/en/__init__.py in __init__(self, **overrides)
#      32         # Special-case hack for loading the GloVe vectors, to support <1.0
#      33         overrides = fix_glove_vectors_loading(overrides)
# ---> 34         Language.__init__(self, **overrides)
#
# /opt/conda/lib/python3.5/site-packages/spacy/language.py in __init__(self, **overrides)
#     277                          else overrides['tagger']
#     278         self.parser    = self.Defaults.create_parser(self) \
# --> 279                          if 'parser' not in overrides \
#     280                          else overrides['parser']
#     281         self.entity    = self.Defaults.create_entity(self) \
#
# /opt/conda/lib/python3.5/site-packages/spacy/language.py in create_parser(cls, nlp, **cfg)
#      98             return None
#      99         else:
# --> 100             return DependencyParser.load(nlp.path / 'deps', nlp.vocab, **cfg)
#     101
#     102     @classmethod
#
# /opt/conda/lib/python3.5/site-packages/spacy/syntax/parser.pyx in spacy.syntax.parser.Parser.load (spacy/syntax/parser.cpp:7073)()
#
# /opt/conda/lib/python3.5/site-packages/thinc/linear/avgtron.pyx in thinc.linear.avgtron.AveragedPerceptron.load (thinc/linear/avgtron.cpp:3514)()
#
# /opt/conda/lib/python3.5/site-packages/preshed/maps.pyx in preshed.maps.PreshMap.__init__ (preshed/maps.cpp:1193)()
#
# /opt/conda/lib/python3.5/site-packages/preshed/maps.pyx in preshed.maps.map_init (preshed/maps.cpp:3058)()
#
# /opt/conda/lib/python3.5/site-packages/cymem/cymem.pyx in cymem.cymem.Pool.alloc (cymem/cymem.cpp:1091)()
#
# MemoryError: Error assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytes

# %%
wiki_mongo_database = cli.wiki_mongo_database
wiki_mongo_collection = cli.wiki_mongo_database.wiki_mongo_collection
wiki_mongo_collection.count()

# %%
df = pd.DataFrame(list(cli.wiki_mongo_database.wiki_mongo_collection.find({})))
df.sort(columns='clean_content',ascending=True)
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel_launcher.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#
# 5588  Abhyāsa, in Hinduism, is a spiritual practice ...   2944526
# 1731  Abigail Aldrich "Abby" Rockefeller (born 1943)...   4480588
# 1732  Abigail Aldrich "Abby" Rockefeller (November 9...   1942168
# 1728  Abigail Greene "Abby" Aldrich Rockefeller (Oct...   1179999
# 3184  Able Danger was a classified military planning...   2422824
# 1736  Abra Prentice Wilkin (born 1942) is an America...   2881320
# 1737  Abraham Flexner (November 13, 1866 – September...   1627281
# 1738  Abraham Pineo Gesner, ONB (/ˈɡɛsnər/; May 2, 1...    256711
# 1739  Abram Samoilovitch Besicovitch (or Besikovitch...    404566
# 3185  Absolutdata Research and Analytics is a consul...  39829449
# 4512  Abundance estimation comprises all statistical...  42122213
# 4503  An ABX test is a method of comparing two choic...   8103136
# 1191  ACADEMA is a privately held Slovenian engineer...   3500795
# 3226  Academic analytics is basically defined as the...  13292275
# 1740  Acadia National Park is a national park locate...     62671
# 4514  The acceptable quality limit (AQL) is the wors...  17216134
# 4515  Acceptance sampling uses statistical sampling ...  25719356
# 5753  According to the Hindu philosophy, there are s...   1391123
# 4252  According to IFABC Global Web Standards, a uni...   4503685
# 5707  According to Vedic and Hindu philosophy, every...    656993
# 7     The accuracy paradox for predictive analytics ...   3771060
# ...                                                 ...       ...
# 4828  COBWEB is an incremental system for hierarchic...   5477824
# 4848  In statistics, a variable is termed a collider...  28475136
# 4851  A committee machine is a type of artificial ne...   9583985
# 4852  In applied statistics, (e.g., applied to the s...  34308675
# 4855  The following table compares some of the most ...  49119569
# 4857  Competitive learning is a form of unsupervised...  26266110
# 4858  Complete-linkage clustering is one of several ...  28976910
# 4866  Compositional pattern-producing networks (CPPN...  13526929
# 4869  Computational cybernetics is the integration o...   1532719
# 4870  Computational neurogenetic modeling (CNGM) is ...   8402086
# 4872  Conceptual clustering is a machine learning pa...   6979740
# 4884  In statistics, a confidence interval (CI) is a...    280911
# 4888  In statistics, confirmatory factor analysis (C...  11391242
# 4889  In statistics, a confounder (also confounding ...   3105999
# 4890  In the field of machine learning and specifica...    847558
# 4892  In multivariate statistics, the congruence coe...  36029874
# 4893  Conjoint analysis is a survey-based statistica...    296457
# 4896  Clustering is the assignment of objects into g...  21542452
# 4901  In computer science, constrained clustering is...  33391687
# 4918  In computer science, Convolutional Deep Belief...  42368614
# 4930  Clustering is the problem of partitioning data...  21417820
# 4978  The National Museum of History (NMH; Chinese: ...  17783247
# 5108  The Japanese invasion of Taiwan (Chinese and J...   8127750
# 5183  The Republic of Formosa (literally Democratic ...    301940
# 5272  27 Brigade (Chinese: 二七部隊) was a guerrilla for...   8982533
# 5289  The February 28 Incident or February 28 Massac...    159838
# 5347                                                     51038189
# 5650  Kumar Anish is an Indian yoga practitioner who...  38023657
# 5721                                                     17366046
# 5724  Theos Casimir Bernard (1908–1947) was an explo...  31368675
#
#                                           title
# 3182                         Ab Initio Software
# 3183                                Abacus Data
# 4511              Abalone (molecular mechanics)
# 5516                                  Shavaripa
# 1729   Abby Aldrich Rockefeller Folk Art Museum
# 1730  Abby Aldrich Rockefeller Sculpture Garden
# 1733                    Abd al-Rahman al-Bazzaz
# 1734                    Abdallah Salem el-Badri
# 1735                            Abdullah Tariki
# 5588                                    Abhyasa
# 1731                           Abby Rockefeller
# 1732                     Abby Rockefeller Mauzé
# 1728                   Abby Aldrich Rockefeller
# 3184                                Able Danger
# 1736                       Abra Prentice Wilkin
# 1737                            Abraham Flexner
# 1738                       Abraham Pineo Gesner
# 1739             Abram Samoilovitch Besicovitch
# 3185                                Absolutdata
# 4512                       Abundance estimation
# 4503                                   ABX test
# 1191                                    Academa
# 3226              Analytics in higher education
# 1740                       Acadia National Park
# 4514                   Acceptable quality limit
# 4515                        Acceptance sampling
# 5753                               Yoga-darsana
# 4252                                Unique user
# 5707                        Seven stages (Yogi)
# 7                              Accuracy paradox
# ...                                         ...
# 4828                        Cobweb (clustering)
# 4848                    Collider (epidemiology)
# 4851                          Committee machine
# 4852                     Common-method variance
# 4855       Comparison of deep learning software
# 4857                       Competitive learning
# 4858                Complete-linkage clustering
# 4866    Compositional pattern-producing network
# 4869                  Computational cybernetics
# 4870        Computational neurogenetic modeling
# 4872                      Conceptual clustering
# 4884                        Confidence interval
# 4888               Confirmatory factor analysis
# 4889                                Confounding
# 4890                           Confusion matrix
# 4892                     Congruence coefficient
# 4893                          Conjoint analysis
# 4896                       Consensus clustering
# 4901                     Constrained clustering
# 4918         Convolutional Deep Belief Networks
# 4930                     Correlation clustering
# 4978                 National Museum of History
# 5108         Japanese invasion of Taiwan (1895)
# 5183                        Republic of Formosa
# 5272                                 27 Brigade
# 5289                       February 28 Incident
# 5347      Template:Taiwan independence movement
# 5650                                Kumar Anish
# 5721                   Template:Hindu Practices
# 5724                      Theos Casimir Bernard
#
# [5762 rows x 6 columns]

# %%
def cleaner(text):
    text = text.lower()
    text = re.sub('<.{0,3}>',' ',text)
    text = re.sub('{.*\.*}',' ',text)
    text = re.sub('{.*\+.*}',' ',text)
    #text = re.sub('[\W]',' ',text)
    text = re.sub('[^a-z]',' ',text)
    text = ' '.join( [w for w in text.split() if len(w)>1] )
    #text = re.sub('/(?<!\S).(?!\S)\s*/',' ',text)
    text = re.sub('aa','a',text)
    text = re.sub('[0-9]','',text)
    text = re.sub('\s+',' ',text)
    text = ' '.join([i.lemma_ for i in nlp(text) if i.orth_ not in STOP_WORDS])
    return text

# %%
for i in range(wiki_mongo_collection.count()):
    cur = wiki_mongo_collection.find()[i]
    content = cur['content']
    cleaned_content = cleaner(content)
    wiki_mongo_collection.update_one(
        {'content':content},
        {'$set': {'clean_content':cleaner(content)}}
        )

# %%
wiki_mongo_collection.delete_many({'title':{'$regex':"File:.*"}})
wiki_mongo_collection.delete_many({"clean_content":''})
wiki_mongo_collection.delete_many( { 'clean_content': None })
wiki_mongo_collection.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ac7a82979573> in <module>()
# ----> 1 wiki_mongo_collection.delete_many({'title':{'$regex':"File:.*"}})
#       2 wiki_mongo_collection.delete_many({"clean_content":''})
#       3 wiki_mongo_collection.delete_many( { 'clean_content': None })
#       4 wiki_mongo_collection.count()
#
# NameError: name 'wiki_mongo_collection' is not defined

# %%
df[df['clean_content'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [_id, category, clean_content, content, pageid, title]
# Index: []

# %%
# Out:
# 5665

# %%
df = pd.DataFrame(list(cli.wiki_mongo_database.wiki_mongo_collection.find({})))
print(df.count())
df.sort('clean_content').head(10)
# Out:
# _id              5665
# category         5665
# clean_content    5665
# content          5665
# pageid           5665
# title            5665
# dtype: int64
# /opt/conda/lib/python3.5/site-packages/ipykernel_launcher.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   This is separate from the ipykernel package so we can avoid doing imports until
#                            _id                        category  \
# 1595  591c794bad28cdd96d817db8  Geographic information systems
# 3182  591c9c64ad28cdd96d819554           Business intelligence
# 3183  591c9c66ad28cdd96d819557           Business intelligence
# 4508  5920052aad28cdd96d84e854             Statistical_methods
# 5422  592072bbad28cdd96d85096e                            Yoga
# 1729  591c9454ad28cdd96d8186ec                       Petroleum
# 1730  591c9455ad28cdd96d8186ee                       Petroleum
# 1733  591c9457ad28cdd96d8186f4                       Petroleum
# 1734  591c9457ad28cdd96d8186f6                       Petroleum
# 1735  591c9458ad28cdd96d8186f8                       Petroleum
#
#                                           clean_content  \
# 1595
# 3182  ab initio software american multinational ente...
# 3183  abacus datum canadian polling market research ...
# 4508  abalone general purpose molecular dynamic mole...
# 5422  abara sanskrit shavaripa tibetan indian buddhi...
# 1729  abby aldrich rockefeller folk art museum museu...
# 1730  abby aldrich rockefeller sculpture garden outd...
# 1733  abd al rahman al bazzaz arabic politician refo...
# 1734  abdalla salem el badri bear libyan official se...
# 1735  abdullah ibn hamoud tariki march september ara...
#
#                                                 content    pageid  \
# 1595                                                     47106758
# 3182  Ab Initio Software is an American multinationa...   1416977
# 3183  Abacus Data is a Canadian polling and market r...  35005889
# 4508  Abalone is a general purpose molecular dynamic...  22497840
# 5422  Śabara in Sanskrit or Shavaripa in Tibetan is ...  36465504
# 1729  The Abby Aldrich Rockefeller Folk Art Museum i...  32750045
# 1730  The Abby Aldrich Rockefeller Sculpture Garden ...  45295028
# 1733  Abd al-Rahman al-Bazzaz (Arabic: عبد الرحمن ال...    806114
# 1734  Abdalla Salem el-Badri (born 25 May 1940) is a...  31212437
# 1735  Abdullah ibn Hamoud Tariki (19 March 1919 – 7 ...   7996840
#
#                                           title
# 1595                Template:OpenStreetMap maps
# 3182                         Ab Initio Software
# 3183                                Abacus Data
# 4508              Abalone (molecular mechanics)
# 5422                                  Shavaripa
# 1729   Abby Aldrich Rockefeller Folk Art Museum
# 1730  Abby Aldrich Rockefeller Sculpture Garden
# 1733                    Abd al-Rahman al-Bazzaz
# 1734                    Abdallah Salem el-Badri
# 1735                            Abdullah Tariki
